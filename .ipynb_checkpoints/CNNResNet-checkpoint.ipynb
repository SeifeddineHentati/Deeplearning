# %%
import torch
from torchvision import datasets, models, transforms

# %%
#pytorch torchvision documentation if you use pretrained models...
#...images has to be standardized using these constants
mean =  [0.485, 0.456, 0.406] #mean
std = [0.229, 0.224, 0.225] #standard deviation

# %%
#allows chaining of transformations
#random transforms on the training data so the model doesnt pick up a pattern
train_transform = transforms.Compose(
[
    transforms.Resize(256),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])
#for the test it doesn need random transforms
test_transform = transforms.Compose(
[
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean,std)
])

# %%
import zipfile
zip = zipfile.ZipFile('datasets/flowers_.zip')
zip.extractall('datasets')

# %%
data_dir = 'datasets/flowers'

# %%
image_datasets = {}

# %%
image_datasets['train'] = datasets.ImageFolder(data_dir+'/train',
                                               train_transform)

# %%
image_datasets['train']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3780
#     Root location: datasets/flowers/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
image_datasets['test'] = datasets.ImageFolder(data_dir+'/test',
                                             test_transform)

# %%
print("Training data size - %d" % len(image_datasets['train']))
print("Test data size - %d" % len(image_datasets['test']))
# Out:
# Training data size - 3780
# Test data size - 4323

# %%
image_datasets['test']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 4323
#     Root location: datasets/flowers/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
class_names= image_datasets['train'].classes
class_names
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
dataloaders = {}

# %%
dataloaders['train'] = torch.utils.data.DataLoader(image_datasets['train'],
                                                 batch_size=8,
                                                 shuffle=True,
                                                 num_workers=4)

# %%
dataloaders['test'] = torch.utils.data.DataLoader(image_datasets['test'],
                                            batch_size=8,
                                            shuffle=False,
                                            num_workers=4)

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x1c9a62c6130>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x1c9a62c63a0>}

# %%
inputs, labels = next(iter(dataloaders['train']))
inputs.shape , labels.shape
#input should be batch_size, num_channels, height, width
#4 dimentional tensor
# Out:
# (torch.Size([8, 3, 224, 224]), torch.Size([8]))

# %%
labels 
#categories of flowers
# Out:
# tensor([2, 1, 4, 4, 4, 1, 1, 4])

# %%
import torchvision

inp = torchvision.utils.make_grid(inputs)
inp.shape
# Out:
# torch.Size([3, 228, 1810])

# %%
inp.max()
#check the larget R ,G or B  number should be between 0 => 1
# Out:
# tensor(2.6400)

# %%
import numpy as np

np.clip(inp,0 ,1).max() #scale the values to 0 => 1 as desired
# Out:
# tensor(1.)

# %%
inp.numpy().transpose((1,2,0)).shape
# Out:
# (228, 1810, 3)

# %%
import matplotlib.pyplot as plt 

plt.ion()

# %%
def img_show(inp, title= None):
    
    inp = inp.numpy().transpose((1,2,0))
    inp = std * inp + mean
    inp = np.clip(inp,0,1)
    
    plt.figure(figsize=(16,4))
    plt.axis('off')
    plt.imshow(inp)
    if title is not None:
        plt.title(title)

# %%
img_show(inp,title=[class_names[x] for x in labels])

# %%
#download pretrained ResNet model
model = models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to C:\Users\seife/.cache\torch\hub\checkpoints\resnet18-5c106cde.pth
# ...

# %%
#let s get the number of features in this pretrained model
num_ftrs = model.fc.in_features #linear layer present in this model
num_ftrs
# Out:
# 512

# %%
import torch.nn as nn

# %%
model.fc = nn.Linear(num_ftrs, 5) #classifies our data into 5 categories ...
#...instead of the standard 512 features (categories) replace the linear layer

# %%
criterion = nn.CrossEntropyLoss()

# %%
import torch.optim as optim


optimizer = optim.SGD(model.parameters(), #stochastic gradient descent optimizer
                     lr=0.001, #learning rate
                     momentum=0.9) #momentum to accelerate our learning

from torch.optim import lr_scheduler
#learning rate scheduler
#tweaks our learning rate as our model is closer to convergence
exp_lr_scheduler = lr_scheduler.StepLR(optimizer,
                                      step_size=7, #reduce learning rate by
                                      gamma=0.1)   #0.1 every 7 epochs

# %%
def calculate_accuracy(phase, running_loss, running_corrects):
    epoch_loss = running_loss / len(image_datasets[phase])
    epoch_acc = running_corrects.double() /len(image_datasets[phase])
    
    print('{} Loss: {:,.4f} Acc: {:,.4f}'.format(phase, epoch_loss, epoch_acc))
    return (epoch_loss,epoch_acc)

# %%
def phase_train(model, criterion, optimizer, scheduler):
    
    scheduler.step()
    model.train()
    running_loss = 0.0
    running_corrects = 0
    
    for inputs, labels in dataloaders['train']:
        
        optimizer.zero_grad()
        with torch.set_grad_enabled(True):
            outputs = model(inputs)
            _, preds = torch.max(outputs,1)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds== labels.data)
        
        calculate_accuracy('train',running_loss,running_corrects)

# %%
import copy

# %%
best_acc = 0.0
def phase_test(model, criterion, optimizer):
    
    model.eval()
    running_loss =0.0
    running_corrects= 0
    
    global best_acc
    
    for inputs,labels in dataloaders['test']:
        
        optimizer.zero_grad()
        
        with torch.no_grad():
            outputs = model(inputs)
            _,preds = torch.max(outputs,1)
            loss = criterion(outputs, labels)
            
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        
    epoch_loss, epoch_acc = calculate_accuracy('test',running_loss,running_corrects)
    if epoch_acc > best_acc:
        best_acc = epoch_acc
        best_model_wts = copy.deepcopy(model.state_dict())
    
    return best_model_wts

# %%
def build_model(model, criterion, optimizer, scheduler, num_epochs=10):
    best_model_wts = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch,num_epochs-1))
        print('-'*10)
        
        phase_train(model,criterion, optimizer, scheduler)
        best_model_wts = phase_test(model,criterion,optimizer)
        print()
    
    print('Best test Acc: {:.4f}'.format(best_acc))
    
    model.load_state_dict(best_model_wts)
    return model

# %%
model =  build_model(model,
                     criterion,
                    optimizer,
                    exp_lr_scheduler,
                    num_epochs=1)
# Out:
# Epoch 0/0
# ----------
# train Loss: 0.0009 Acc: 0.0019
# train Loss: 0.0018 Acc: 0.0034
# train Loss: 0.0021 Acc: 0.0053
# train Loss: 0.0023 Acc: 0.0074
# train Loss: 0.0024 Acc: 0.0095
# train Loss: 0.0050 Acc: 0.0106
# train Loss: 0.0071 Acc: 0.0119
# train Loss: 0.0082 Acc: 0.0132
# train Loss: 0.0086 Acc: 0.0153
# train Loss: 0.0107 Acc: 0.0167
# train Loss: 0.0118 Acc: 0.0183
# train Loss: 0.0125 Acc: 0.0198
# train Loss: 0.0146 Acc: 0.0214
# train Loss: 0.0155 Acc: 0.0233
# train Loss: 0.0160 Acc: 0.0251
# train Loss: 0.0163 Acc: 0.0272
# train Loss: 0.0177 Acc: 0.0286
# train Loss: 0.0192 Acc: 0.0296
# train Loss: 0.0203 Acc: 0.0315
# train Loss: 0.0209 Acc: 0.0333
# train Loss: 0.0220 Acc: 0.0352
# train Loss: 0.0225 Acc: 0.0370
# train Loss: 0.0241 Acc: 0.0384
# train Loss: 0.0247 Acc: 0.0402
# train Loss: 0.0254 Acc: 0.0421
# train Loss: 0.0256 Acc: 0.0442
# train Loss: 0.0272 Acc: 0.0460
# train Loss: 0.0275 Acc: 0.0481
# train Loss: 0.0294 Acc: 0.0495
# ...

# %%
with torch.no_grad():
    
    inputs, labels = iter(dataloaders['test']).next()
    inp = torchvision.utils.make_grid(inputs)
    
    outputs = model(inputs)
    _,preds = torch.max(outputs,1)
    
    for j in range(len(inputs)):
        inp = inputs.data[j]
        img_show(inp,'predicted:'+class_names[preds[j]])

# %%
frozen_model = models.resnet18(pretrained=True)

# %%
for param in frozen_model.parameters():
    param.requires_grad = False

# %%
frozen_model.fc = nn.Linear(num_ftrs,5)

optimizer = optim.SGD(frozen_model.fc.parameters(),
                     lr=0.001,
                     momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer,
                                       step_size=7,
                                       gamma=0.1)

criterion = nn.CrossEntropyLoss()

best_acc = 0.0

# %%
frozen_model = build_model(frozen_model,
                          criterion,
                          optimizer,
                          exp_lr_scheduler,
                          num_epochs=1)
# Out:
# Epoch 0/0
# ----------
# train Loss: 0.0048 Acc: 0.0005
# train Loss: 0.0089 Acc: 0.0005
# train Loss: 0.0118 Acc: 0.0013
# train Loss: 0.0158 Acc: 0.0019
# train Loss: 0.0190 Acc: 0.0032
# train Loss: 0.0231 Acc: 0.0034
# train Loss: 0.0272 Acc: 0.0037
# train Loss: 0.0308 Acc: 0.0042
# train Loss: 0.0346 Acc: 0.0048
# train Loss: 0.0381 Acc: 0.0050
# train Loss: 0.0410 Acc: 0.0061
# train Loss: 0.0446 Acc: 0.0069
# train Loss: 0.0483 Acc: 0.0074
# train Loss: 0.0524 Acc: 0.0077
# train Loss: 0.0552 Acc: 0.0085
# train Loss: 0.0588 Acc: 0.0090
# train Loss: 0.0621 Acc: 0.0095
# train Loss: 0.0649 Acc: 0.0103
# train Loss: 0.0680 Acc: 0.0111
# train Loss: 0.0710 Acc: 0.0119
# train Loss: 0.0741 Acc: 0.0127
# train Loss: 0.0773 Acc: 0.0135
# train Loss: 0.0805 Acc: 0.0138
# train Loss: 0.0839 Acc: 0.0138
# train Loss: 0.0864 Acc: 0.0151
# train Loss: 0.0885 Acc: 0.0161
# train Loss: 0.0914 Acc: 0.0172
# train Loss: 0.0941 Acc: 0.0183
# train Loss: 0.0968 Acc: 0.0190
# ...

# %%
with torch.no_grad():
    
    inputs , labels = iter(dataloaders['test']).next()
    inp = torchvision.utils.make_grid(inputs)
    
    outputs = frozen_model(inputs)
    _, preds = torch.max(outputs,1)
    
    for j in range(len(inputs)):
        inp = inputs.data[j]
        img_show(inp,'predicted: '+ class_names[preds[j]])
